# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# for Notebook
# %matplotlib inline

# %%
def draw(G, pos, measures, measure_name):
    
    nodes = nx.draw_networkx_nodes(G, pos, node_size=250, cmap=plt.cm.plasma, 
                                   node_color=list(measures.values()),
                                   nodelist=measures.keys())
    nodes.set_norm(mcolors.SymLogNorm(linthresh=0.01, linscale=1, base=10))
    # labels = nx.draw_networkx_labels(G, pos)
    edges = nx.draw_networkx_edges(G, pos)

    plt.title(measure_name)
    plt.colorbar(nodes)
    plt.axis('off')
    plt.show()

# %%
G = nx.karate_club_graph()
pos = nx.spring_layout(G, seed=675)

# %%
DiG = nx.DiGraph()
DiG.add_edges_from([(2, 3), (3, 2), (4, 1), (4, 2), (5, 2), (5, 4),
                    (5, 6), (6, 2), (6, 5), (7, 2), (7, 5), (8, 2),
                    (8, 5), (9, 2), (9, 5), (10, 5), (11, 5)])
dpos = {1: [0.1, 0.9], 2: [0.4, 0.8], 3: [0.8, 0.9], 4: [0.15, 0.55],
        5: [0.5,  0.5], 6: [0.8,  0.5], 7: [0.22, 0.3], 8: [0.30, 0.27],
        9: [0.38, 0.24], 10: [0.7,  0.3], 11: [0.75, 0.35]}

# %% [markdown]
# Centrality

# %%
draw(G, pos, nx.degree_centrality(G), 'Degree Centrality')

# %%
Eigenvector

# %%
draw(G, pos, nx.eigenvector_centrality(G), 'Eigenvector Centrality')

# %% [markdown]
# Katz

# %%
draw(G, pos, nx.katz_centrality(G, alpha=0.1, beta=1.0), 'Katz Centrality')

# %% [markdown]
# Page Rank

# %%
draw(G, dpos, nx.pagerank(G, alpha=0.85), 'PageRank')
draw(DiG, dpos, nx.pagerank(DiG, alpha=0.85), 'DiGraph PageRank')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_16591/77517406.py in <module>
#       2 #dpos = nx.spring_layout(dG, seed=675)
#       3 #draw(dG, dpos, nx.pagerank(dG, alpha=0.85), 'PageRank')
# ----> 4 draw(DiG, dpos, nx.pagerank(DiG, alpha=0.85), 'DiGraph PageRank')
#       5
#
# ~/anaconda3/lib/python3.8/site-packages/networkx/algorithms/link_analysis/pagerank_alg.py in pagerank(G, alpha, personalization, max_iter, tol, nstart, weight, dangling)
#     106        The PageRank citation ranking: Bringing order to the Web. 1999
#     107        http://dbpubs.stanford.edu:8090/pub/showDoc.Fulltext?lang=en&doc=1999-66&format=pdf
# --> 108
#     109     """
#     110     return _pagerank_scipy(
#
# ~/anaconda3/lib/python3.8/site-packages/networkx/algorithms/link_analysis/pagerank_alg.py in pagerank_scipy(G, alpha, personalization, max_iter, tol, nstart, weight, dangling)
#     467
#     468     # initial vector
# --> 469     if nstart is None:
#     470         x = np.repeat(1.0 / N, N)
#     471     else:
#
# ~/anaconda3/lib/python3.8/site-packages/networkx/convert_matrix.py in to_scipy_sparse_array(G, nodelist, dtype, weight, format)
#     907
#     908     As stated above, the argument "nonedge" is useful especially when there are
# --> 909     actually edges with weight 0 in the graph. Setting a nonedge value different than 0,
#     910     makes it much clearer to differentiate such 0-weighted edges and actual nonedge values.
#     911
#
# AttributeError: module 'scipy.sparse' has no attribute 'coo_array'
